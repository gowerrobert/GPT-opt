# %% [markdown]
# ./slurm_scripts/submit.sh  scripts/run_fineweb1B_adam_fista.sh param_configs/attn_fista_rho_mu_sweep.json small_fista  16

# %%
from sweep_utils import *

# %%
param_configs = "../param_configs/attn_fista_rho_mu_sweep.json"
script_name = "../scripts/run_fineweb1B_adam_fista.sh"
df, missing = load_sweep_jsons(param_configs, script_name)
# Out:
# /mnt/home/tparshakova/Documents/GPT-opt
# 40 40
# unused={'attn_fista_adamw-lr-0.001-constant-linear-61e109dfd38c8f9c681636aa35377950.json', 'attn_fista_adamw-lr-0.001-constant-linear-720df87083dd5b5e1dd243db9892c54c.json'}
# {'attn_max_iter': '100', 'lr': '0.001', 'momentum': 'False', 'mu_frac': '0.1', 'rho_over_lr': '50', 'warm_start': 'False'}
# {'attn_max_iter': '100', 'lr': '0.001', 'momentum': 'False', 'mu_frac': '0.5', 'rho_over_lr': '50', 'warm_start': 'False'}

# %%
df[:5]
# Out:
#                                                 path  final_train_loss  \
# 0  /mnt/home/tparshakova/Documents/GPT-opt/output...          4.251750
# 1  /mnt/home/tparshakova/Documents/GPT-opt/output...          4.377738
# 2  /mnt/home/tparshakova/Documents/GPT-opt/output...          7.651057
# 3  /mnt/home/tparshakova/Documents/GPT-opt/output...          7.718243
# 4  /mnt/home/tparshakova/Documents/GPT-opt/output...          7.657579
#
#    min_val_loss     kq_max   kq_median       kq_mean attn_max_iter     lr  \
# 0      4.241254       58.5       37.25  3.901212e+01           100  0.001
# 1      4.367407       33.0       18.00  1.956984e+01           100  0.001
# 2      7.565652   417792.0   344064.00  2.893562e+05           100  0.001
# 3      7.719246  4325376.0  3325952.00  3.276972e+06           100  0.001
# 4      7.643188   501760.0   409600.00  3.408923e+05           100  0.001
#
#   momentum mu_frac rho_over_lr warm_start
# 0    False    0.05         0.1      False
# 1    False    0.01        0.01      False
# 2    False    0.05          50      False
# 3    False   0.005         100      False
# 4    False    0.01          10      False

# %%
sorted(df["mu_frac"].unique()), sorted(df["rho_over_lr"].unique())
# Out:
# (['0.005', '0.01', '0.05', '0.1', '0.5'],
#  ['0.01', '0.1', '0.5', '1', '10', '100', '5', '50'])

# %%
plot_heatmat_grid(df)
